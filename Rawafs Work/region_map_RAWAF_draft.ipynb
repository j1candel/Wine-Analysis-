# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import pprint
import urllib.parse

# Import API key
from my_api_config import g_key
from my_api_config import api_key

# %%
geo_test_pd = pd.read_csv('../Resources/geo_test100.csv', encoding='utf-8')
del geo_test_pd['Unnamed: 0']
del geo_test_pd['Unnamed: 0.1']
geo_test_pd
# Out:
#    country                                        description  \
# 0       US  This inexpensive white wine does a good job of...
# 1       US  The fruit intensity and depth in this full-bod...
# 2    Italy  This is a sharply focused expression of the Bu...
# 3       US  Incredibly rich blackberry-jam aromas meet wit...
# 4       US  The expected aromas of cut grass and cat pee g...
# ..     ...                                                ...
# 95   Italy  This barrique-aged Chardonnay opens with delic...
# 96   Spain  Savory and deep given the price, with dark col...
# 97   Italy  This is aged for two years in French oak to sh...
# 98  Canada  Tannic and astringent at first taste, this win...
# 99   Italy  Red rose, mature wild berry, dark cooking spic...
#
#                        designation  points  price          province  \
# 0                              NaN      85   10.0        California
# 1                  Single Vineyard      93   72.0        California
# 2                           Bussia      91   52.0          Piedmont
# 3                              NaN      93   42.0        California
# 4                              NaN      87   15.0        California
# ..                             ...     ...    ...               ...
# 95               Benefizio Riserva      89   45.0           Tuscany
# 96                     Riscal 1860      86    9.0    Northern Spain
# 97                             NaN      89   32.0          Piedmont
# 98                       Qwam Qwmt      89   35.0  British Columbia
# 99  Rocche dell'Annunziata Riserva      94  180.0          Piedmont
#
#                                 region_1       region_2  \
# 0                          Central Coast  Central Coast
# 1                        Anderson Valley            NaN
# 2                                 Barolo            NaN
# 3      Paso Robles Willow Creek District  Central Coast
# 4                            Edna Valley  Central Coast
# ..                                   ...            ...
# 95                                Pomino            NaN
# 96  Vino de la Tierra de Castilla y León            NaN
# 97                            Barbaresco            NaN
# 98                       Okanagan Valley            NaN
# 99                                Barolo            NaN
#
#                                                 title             variety  \
# 0             Tamás 2008 Pinot Grigio (Central Coast)        Pinot Grigio
# 1   Donum 2013 Single Vineyard Pinot Noir (Anderso...          Pinot Noir
# 2              Giacosa Fratelli 2004 Bussia  (Barolo)            Nebbiolo
# 3   Dunning Vineyards 2013 Cabernet Sauvignon (Pas...  Cabernet Sauvignon
# 4   Edna Valley Vineyard 2013 Sauvignon Blanc (Edn...     Sauvignon Blanc
# ..                                                ...                 ...
# 95  Marchesi de' Frescobaldi 2012 Benefizio Riserv...          Chardonnay
# 96  Riscal 2006 Riscal 1860 Tempranillo (Vino de l...         Tempranillo
# 97                             Bosio 2007  Barbaresco            Nebbiolo
# 98  Nk'Mip Cellars 2009 Qwam Qwmt Syrah (Okanagan ...               Syrah
# 99  Paolo Scavino 2009 Rocche dell'Annunziata Rise...            Nebbiolo
#
#                       winery
# 0                      Tamás
# 1                      Donum
# 2           Giacosa Fratelli
# 3          Dunning Vineyards
# 4       Edna Valley Vineyard
# ..                       ...
# 95  Marchesi de' Frescobaldi
# 96                    Riscal
# 97                     Bosio
# 98            Nk'Mip Cellars
# 99             Paolo Scavino
#
# [100 rows x 11 columns]

# %%
geo_test_pd["winery"][0], geo_test_pd["province"][0],geo_test_pd["description"][0]
# Out:
# ('Tamás',
#  'California',
#  'This inexpensive white wine does a good job of being dry and ultracrisp in acidity, which gets the mouth watering. It offers pleasant flavors of Lifesaver candy pineapples and lemons, with a hint of vanilla.')

# %%
# Set parameters to search for locations.

query = f'{geo_test_pd["winery"][0]},winery,{geo_test_pd["region_1"][0]},{geo_test_pd["region_2"][0]}'
place = urllib.parse.quote(query)
province = urllib.parse.quote(geo_test_pd["province"][0])

# base url
# base_url = (f'https://api.opencagedata.com/geocode/v1/json?q={place}&key={api_key}')
base_url = (f'https://api.opencagedata.com/geocode/v1/json?q={place}%2C%20{province}&key={api_key}')
# run a request using our params dictionary
response = requests.get(base_url).json()
pprint.pprint(response)
# Out:
# {'documentation': 'https://opencagedata.com/api',
#  'licenses': [{'name': 'see attribution guide',
#                'url': 'https://opencagedata.com/credits'}],
#  'rate': {'limit': 2500, 'remaining': 2499, 'reset': 1602028800},
#  'results': [{'annotations': {'DMS': {'lat': "35° 18' 14.10840'' N",
#                                       'lng': "119° 56' 34.02240'' W"},
#                               'FIPS': {'state': '06'},
#                               'MGRS': '11SKV3242310720',
#                               'Maidenhead': 'DM05ah62uw',
#                               'Mercator': {'x': -13351969.639,
#                                            'y': 4180565.633},
#                               'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=17/35.30392/-119.94278&layers=N',
#                                       'url': 'https://www.openstreetmap.org/?mlat=35.30392&mlon=-119.94278#map=17/35.30392/-119.94278'},
#                               'UN_M49': {'regions': {'AMERICAS': '019',
#                                                      'NORTHERN_AMERICA': '021',
#                                                      'US': '840',
#                                                      'WORLD': '001'},
#                                          'statistical_groupings': ['MEDC']},
#                               'callingcode': 1,
#                               'currency': {'alternate_symbols': ['US$'],
#                                            'decimal_mark': '.',
#                                            'disambiguate_symbol': 'US$',
#                                            'html_entity': '$',
#                                            'iso_code': 'USD',
#                                            'iso_numeric': '840',
#                                            'name': 'United States Dollar',
#                                            'smallest_denomination': 1,
#                                            'subunit': 'Cent',
#                                            'subunit_to_unit': 100,
#                                            'symbol': '$',
#                                            'symbol_first': 1,
#                                            'thousands_separator': ','},
#                               'flag': '🇺🇸',
#                               'geohash': '9q68yduk4x6pbk8wjxmp',
#                               'qibla': 21.85,
#                               'roadinfo': {'drive_on': 'right',
#                                            'road': 'Central Valley Trl',
#                                            'speed_in': 'mph'},
#                               'sun': {'rise': {'apparent': 1601992800,
#                                                'astronomical': 1601987760,
#                                                'civil': 1601991300,
#                                                'nautical': 1601989560},
#                                       'set': {'apparent': 1601948040,
#                                               'astronomical': 1601953080,
#                                               'civil': 1601949600,
#                                               'nautical': 1601951340}},
#                               'timezone': {'name': 'America/Los_Angeles',
#                                            'now_in_dst': 1,
#                                            'offset_sec': -25200,
#                                            'offset_string': '-0700',
#                                            'short_name': 'PDT'},
#                               'what3words': {'words': 'junior.browsed.cookbooks'}},
#               'components': {'ISO_3166-1_alpha-2': 'US',
#                              'ISO_3166-1_alpha-3': 'USA',
#                              '_category': 'road',
#                              '_type': 'road',
#                              'continent': 'North America',
#                              'country': 'United States of America',
#                              'country_code': 'us',
#                              'road': 'Central Valley Trl',
#                              'state': 'California',
#                              'state_code': 'CA',
#                              'town': 'Santa Margarita'},
#               'confidence': 3,
#               'formatted': 'Central Valley Trl, Santa Margarita, CA, United '
#                            'States of America',
#               'geometry': {'lat': 35.303919, 'lng': -119.942784}},
#              {'annotations': {'DMS': {'lat': "37° 15' 0.79200'' N",
#                                       'lng': "119° 45' 4.53600'' W"},
#                               'FIPS': {'state': '06'},
#                               'MGRS': '11SKB5598226178',
#                               'Maidenhead': 'DM07cg90ub',
#                               'Mercator': {'x': -13330649.285,
#                                            'y': 4448175.919},
#                               'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=17/37.25022/-119.75126&layers=N',
#                                       'url': 'https://www.openstreetmap.org/?mlat=37.25022&mlon=-119.75126#map=17/37.25022/-119.75126'},
#                               'UN_M49': {'regions': {'AMERICAS': '019',
#                                                      'NORTHERN_AMERICA': '021',
#                                                      'US': '840',
#                                                      'WORLD': '001'},
#                                          'statistical_groupings': ['MEDC']},
#                               'callingcode': 1,
#                               'currency': {'alternate_symbols': ['US$'],
#                                            'decimal_mark': '.',
#                                            'disambiguate_symbol': 'US$',
#                                            'html_entity': '$',
#                                            'iso_code': 'USD',
#                                            'iso_numeric': '840',
#                                            'name': 'United States Dollar',
#                                            'smallest_denomination': 1,
#                                            'subunit': 'Cent',
#                                            'subunit_to_unit': 100,
#                                            'symbol': '$',
#                                            'symbol_first': 1,
#                                            'thousands_separator': ','},
#                               'flag': '🇺🇸',
#                               'geohash': '9qdgfvpy32k9sgj3gg7h',
#                               'qibla': 21.64,
#                               'roadinfo': {'drive_on': 'right',
#                                            'speed_in': 'mph'},
#                               'sun': {'rise': {'apparent': 1601992860,
#                                                'astronomical': 1601987640,
#                                                'civil': 1601991300,
#                                                'nautical': 1601989500},
#                                       'set': {'apparent': 1601947920,
#                                               'astronomical': 1601953140,
#                                               'civil': 1601949480,
#                                               'nautical': 1601951280}},
#                               'timezone': {'name': 'America/Los_Angeles',
#                                            'now_in_dst': 1,
#                                            'offset_sec': -25200,
#                                            'offset_string': '-0700',
#                                            'short_name': 'PDT'},
#                               'what3words': {'words': 'surgical.everyone.unrest'}},
#               'bounds': {'northeast': {'lat': 42.009517, 'lng': -114.131211},
#                          'southwest': {'lat': 32.528832, 'lng': -124.482003}},
#               'components': {'ISO_3166-1_alpha-2': 'US',
#                              'ISO_3166-1_alpha-3': 'USA',
#                              '_category': 'place',
#                              '_type': 'state',
#                              'continent': 'North America',
#                              'country': 'United States of America',
#                              'country_code': 'us',
#                              'state': 'California',
#                              'state_code': 'CA'},
#               'confidence': 1,
#               'formatted': 'California, United States of America',
#               'geometry': {'lat': 37.25022, 'lng': -119.75126}}],
#  'status': {'code': 200, 'message': 'OK'},
#  'stay_informed': {'blog': 'https://blog.opencagedata.com',
#                    'twitter': 'https://twitter.com/OpenCage'},
#  'thanks': 'For using an OpenCage API',
#  'timestamp': {'created_http': 'Tue, 06 Oct 2020 02:05:24 GMT',
#                'created_unix': 1601949924},
#  'total_results': 2}

# %%
base_url
# Out:
# 'https://api.opencagedata.com/geocode/v1/json?q=Tam%C3%A1s%2Cwinery%2CCentral%20Coast%2CCentral%20Coast%2C%20California&key=4a24b7ddf8104a17b9eae6c7fa8f06b0'

# %%
province
# Out:
# 'California'

# %%
response['results'][0]['confidence']
# Out:
# 3

# %%
len(response['results'])
# Out:
# 2

# %%
# Selecting responses with medium to high confidence score
num_responses = len(response['results'])

for x in range(num_responses):
#     print(x)
    confidence = response['results'][x]['confidence'] 
    if confidence >=5:
        print(confidence)
    else:
        print(f'not confident: {confidence}')

# len(response['results'])
# Out:
# not confident: 3
# not confident: 1

# %%
# Hit the OpenCageData API for each winery.
# Set up a Dictionary to hold reponse info for:
town=[]
lat=[]
lng=[]

print("Beginning search for nearby wineries... \n-----------------------------")

# Loop through the geo_test_pd and get a lat/long for each winery
for index, row in geo_test_pd.iterrows():
   
    query = f'{row["winery"]},{row["region_1"]},{row["province"]},{row["country"]}'
    place = urllib.parse.quote(query)
#     province = urllib.parse.quote(row["province"])
#     country = row["country"]

    base_url = (f'https://api.opencagedata.com/geocode/v1/json?q={place}&key={api_key}')

    try:
        print(f"Searching for winery {query}")
        response = requests.get(base_url).json()
#         print(place)
#         print(province)
        town.append(response['results'][0]['components']['town'])
        lat.append(response['results'][0]['geometry']['lat'])
        lng.append(response['results'][0]['geometry']['lng'])
        print(f'---> {query} appended')
        print(" ")
    except:
        print(f"X--X No wineries found. Skipping {query}...")
        print(" ")
        town.append(None)
        lat.append(None)
        lng.append(None)
# Out:
# Beginning search for nearby wineries...
# -----------------------------
# Searching for winery Tamás,Central Coast,California,US
# ---> Tamás,Central Coast,California,US appended
#
# Searching for winery Donum,Anderson Valley,California,US
# ---> Donum,Anderson Valley,California,US appended
#
# Searching for winery Giacosa Fratelli,Barolo,Piedmont,Italy
# ---> Giacosa Fratelli,Barolo,Piedmont,Italy appended
#
# Searching for winery Dunning Vineyards,Paso Robles Willow Creek District,California,US
# ---> Dunning Vineyards,Paso Robles Willow Creek District,California,US appended
#
# Searching for winery Edna Valley Vineyard,Edna Valley,California,US
# X--X No wineries found. Skipping Edna Valley Vineyard,Edna Valley,California,US...
#
# Searching for winery Château Sainte Marie,Bordeaux Supérieur,Bordeaux,France
# ---> Château Sainte Marie,Bordeaux Supérieur,Bordeaux,France appended
#
# Searching for winery Chateau Ste. Michelle,Horse Heaven Hills,Washington,US
# X--X No wineries found. Skipping Chateau Ste. Michelle,Horse Heaven Hills,Washington,US...
#
# Searching for winery Casanel,Middleburg,Virginia,US
# ---> Casanel,Middleburg,Virginia,US appended
#
# Searching for winery Bella Luna,San Benito County,California,US
# ---> Bella Luna,San Benito County,California,US appended
#
# Searching for winery Tenute Mater Domini,Salento,Southern Italy,Italy
# X--X No wineries found. Skipping Tenute Mater Domini,Salento,Southern Italy,Italy...
#
# Searching for winery Arrogant Frog,Pays d'Oc,Languedoc-Roussillon,France
# X--X No wineries found. Skipping Arrogant Frog,Pays d'Oc,Languedoc-Roussillon,France...
#
# Searching for winery PianCornello,Brunello di Montalcino,Tuscany,Italy
# ---> PianCornello,Brunello di Montalcino,Tuscany,Italy appended
#
# Searching for winery Díaz Bayo,Ribera del Duero,Northern Spain,Spain
# X--X No wineries found. Skipping Díaz Bayo,Ribera del Duero,Northern Spain,Spain...
#
# Searching for winery Jean-Luc Baldès,Cahors,Southwest France,France
# X--X No wineries found. Skipping Jean-Luc Baldès,Cahors,Southwest France,France...
#
# Searching for winery Fattoria La Rivolta,Sannio,Southern Italy,Italy
# X--X No wineries found. Skipping Fattoria La Rivolta,Sannio,Southern Italy,Italy...
#
# Searching for winery Three Rivers,Columbia Valley (WA),Washington,US
# ---> Three Rivers,Columbia Valley (WA),Washington,US appended
#
# Searching for winery Brick & Mortar,Sonoma Coast,California,US
# ---> Brick & Mortar,Sonoma Coast,California,US appended
#
# Searching for winery Anthony Road,Finger Lakes,New York,US
# ---> Anthony Road,Finger Lakes,New York,US appended
#
# Searching for winery Talbott,Monterey,California,US
# X--X No wineries found. Skipping Talbott,Monterey,California,US...
#
# Searching for winery Primosic,Collio,Northeastern Italy,Italy
# X--X No wineries found. Skipping Primosic,Collio,Northeastern Italy,Italy...
#
# Searching for winery Wellington,Sonoma Valley,California,US
# ---> Wellington,Sonoma Valley,California,US appended
#
# Searching for winery Taz,Santa Barbara County,California,US
# ---> Taz,Santa Barbara County,California,US appended
#
# Searching for winery Ocaso,Mendoza,Mendoza Province,Argentina
# X--X No wineries found. Skipping Ocaso,Mendoza,Mendoza Province,Argentina...
#
# Searching for winery Mas de Cadenet,Côtes de Provence,Provence,France
# X--X No wineries found. Skipping Mas de Cadenet,Côtes de Provence,Provence,France...
#
# Searching for winery Talamonti,Montepulciano d'Abruzzo,Central Italy,Italy
# X--X No wineries found. Skipping Talamonti,Montepulciano d'Abruzzo,Central Italy,Italy...
#
# Searching for winery Channing Daughters,North Fork of Long Island,New York,US
# ---> Channing Daughters,North Fork of Long Island,New York,US appended
#
# Searching for winery Cave de Cleebourg,Crémant d'Alsace,Alsace,France
# X--X No wineries found. Skipping Cave de Cleebourg,Crémant d'Alsace,Alsace,France...
#
# Searching for winery Bergström,Willamette Valley,Oregon,US
# ---> Bergström,Willamette Valley,Oregon,US appended
#
# Searching for winery Alice White,South Eastern Australia,Australia Other,Australia
# X--X No wineries found. Skipping Alice White,South Eastern Australia,Australia Other,Australia...
#
# Searching for winery Château du Cros,Cadillac Côtes de Bordeaux,Bordeaux,France
# ---> Château du Cros,Cadillac Côtes de Bordeaux,Bordeaux,France appended
#
# Searching for winery Bodegas Mähler-Besse,Jumilla,Levante,Spain
# X--X No wineries found. Skipping Bodegas Mähler-Besse,Jumilla,Levante,Spain...
#
# Searching for winery Von Holt,Russian River Valley,California,US
# ---> Von Holt,Russian River Valley,California,US appended
#
# Searching for winery Sol Rouge,Red Hills Lake County,California,US
# ---> Sol Rouge,Red Hills Lake County,California,US appended
#
# Searching for winery Efeste,Columbia Valley (WA),Washington,US
# ---> Efeste,Columbia Valley (WA),Washington,US appended
#
# Searching for winery PerryMoore,Napa Valley,California,US
# ---> PerryMoore,Napa Valley,California,US appended
#
# Searching for winery El Coto,Rioja,Northern Spain,Spain
# X--X No wineries found. Skipping El Coto,Rioja,Northern Spain,Spain...
#
# Searching for winery Stinson,Monticello,Virginia,US
# ---> Stinson,Monticello,Virginia,US appended
#
# Searching for winery Alain Jaume et Fils,Gigondas,Rhône Valley,France
# X--X No wineries found. Skipping Alain Jaume et Fils,Gigondas,Rhône Valley,France...
#
# Searching for winery Airfield Estates,Yakima Valley,Washington,US
# ---> Airfield Estates,Yakima Valley,Washington,US appended
#
# Searching for winery Château Bellevue de Tayac,Margaux,Bordeaux,France
# ---> Château Bellevue de Tayac,Margaux,Bordeaux,France appended
#
# Searching for winery Planeta,Sicilia,Sicily & Sardinia,Italy
# X--X No wineries found. Skipping Planeta,Sicilia,Sicily & Sardinia,Italy...
#
# Searching for winery àMaurice,Walla Walla Valley (WA),Washington,US
# ---> àMaurice,Walla Walla Valley (WA),Washington,US appended
#
# Searching for winery Domaine Jacques Prieur,Volnay,Burgundy,France
# ---> Domaine Jacques Prieur,Volnay,Burgundy,France appended
#
# Searching for winery Roblar,Sta. Rita Hills,California,US
# ---> Roblar,Sta. Rita Hills,California,US appended
#
# Searching for winery Allegrini,Veronese,Veneto,Italy
# ---> Allegrini,Veronese,Veneto,Italy appended
#
# Searching for winery Rieflé,Alsace,Alsace,France
# X--X No wineries found. Skipping Rieflé,Alsace,Alsace,France...
#
# Searching for winery Sineann,Columbia Valley (WA),Washington,US
# ---> Sineann,Columbia Valley (WA),Washington,US appended
#
# Searching for winery Kali Hart,Monterey County,California,US
# ---> Kali Hart,Monterey County,California,US appended
#
# Searching for winery Pessagno,Santa Lucia Highlands,California,US
# ---> Pessagno,Santa Lucia Highlands,California,US appended
#
# Searching for winery Domaine Coquard Loisson-Fleurot,Echézeaux,Burgundy,France
# X--X No wineries found. Skipping Domaine Coquard Loisson-Fleurot,Echézeaux,Burgundy,France...
#
# Searching for winery Calera,Mt. Harlan,California,US
# ---> Calera,Mt. Harlan,California,US appended
#
# Searching for winery Novy,Russian River Valley,California,US
# ---> Novy,Russian River Valley,California,US appended
#
# Searching for winery Chavet Fils,Menetou-Salon,Loire Valley,France
# X--X No wineries found. Skipping Chavet Fils,Menetou-Salon,Loire Valley,France...
#
# Searching for winery Fidelitas,Red Mountain,Washington,US
# ---> Fidelitas,Red Mountain,Washington,US appended
#
# Searching for winery Ott & Murphy,Columbia Valley (WA),Washington,US
# ---> Ott & Murphy,Columbia Valley (WA),Washington,US appended
#
# Searching for winery Nera,Sforzato di Valtellina,Lombardy,Italy
# X--X No wineries found. Skipping Nera,Sforzato di Valtellina,Lombardy,Italy...
#
# Searching for winery Heron Hill,Finger Lakes,New York,US
# ---> Heron Hill,Finger Lakes,New York,US appended
#
# Searching for winery Tin Barn,Carneros,California,US
# ---> Tin Barn,Carneros,California,US appended
#
# Searching for winery Rochioli,Russian River Valley,California,US
# ---> Rochioli,Russian River Valley,California,US appended
#
# Searching for winery MCV,Paso Robles,California,US
# ---> MCV,Paso Robles,California,US appended
#
# Searching for winery Kevin White,Yakima Valley,Washington,US
# ---> Kevin White,Yakima Valley,Washington,US appended
#
# Searching for winery Gray Ghost,Virginia,Virginia,US
# X--X No wineries found. Skipping Gray Ghost,Virginia,Virginia,US...
#
# Searching for winery Novy,Santa Lucia Highlands,California,US
# ---> Novy,Santa Lucia Highlands,California,US appended
#
# Searching for winery Château de Seguin,Bordeaux,Bordeaux,France
# X--X No wineries found. Skipping Château de Seguin,Bordeaux,Bordeaux,France...
#
# Searching for winery Bouchard Père & Fils,Corton,Burgundy,France
# X--X No wineries found. Skipping Bouchard Père & Fils,Corton,Burgundy,France...
#
# Searching for winery Gustave Lorentz,Crémant d'Alsace,Alsace,France
# X--X No wineries found. Skipping Gustave Lorentz,Crémant d'Alsace,Alsace,France...
#
# Searching for winery El Grifo,Lanzarote,Spanish Islands,Spain
# X--X No wineries found. Skipping El Grifo,Lanzarote,Spanish Islands,Spain...
#
# Searching for winery Blackbird Vineyards,Napa Valley,California,US
# ---> Blackbird Vineyards,Napa Valley,California,US appended
#
# Searching for winery Langtry,Guenoc Valley,California,US
# ---> Langtry,Guenoc Valley,California,US appended
#
# Searching for winery Shalestone,Finger Lakes,New York,US
# ---> Shalestone,Finger Lakes,New York,US appended
#
# Searching for winery Petroni,Sonoma Valley,California,US
# ---> Petroni,Sonoma Valley,California,US appended
#
# Searching for winery August Truth,Mendocino Ridge,California,US
# ---> August Truth,Mendocino Ridge,California,US appended
#
# Searching for winery Lange,Willamette Valley,Oregon,US
# ---> Lange,Willamette Valley,Oregon,US appended
#
# Searching for winery Charles Fournier,Finger Lakes,New York,US
# ---> Charles Fournier,Finger Lakes,New York,US appended
#
# Searching for winery Kirkland Signature,Châteauneuf-du-Pape,Rhône Valley,France
# X--X No wineries found. Skipping Kirkland Signature,Châteauneuf-du-Pape,Rhône Valley,France...
#
# Searching for winery Bricco dei Guazzi,Barbera del Monferrato,Piedmont,Italy
# ---> Bricco dei Guazzi,Barbera del Monferrato,Piedmont,Italy appended
#
# Searching for winery Bianchi,Paso Robles,California,US
# ---> Bianchi,Paso Robles,California,US appended
#
# Searching for winery Thousand Islands Winery,New York,New York,US
# ---> Thousand Islands Winery,New York,New York,US appended
#
# Searching for winery Josef Weger,Alto Adige,Northeastern Italy,Italy
# X--X No wineries found. Skipping Josef Weger,Alto Adige,Northeastern Italy,Italy...
#
# Searching for winery Maximo,Vino de la Tierra de Castilla,Central Spain,Spain
# ---> Maximo,Vino de la Tierra de Castilla,Central Spain,Spain appended
#
# Searching for winery Domaine Calvet-Thunevin,Côtes du Roussillon Villages,Languedoc-Roussillon,France
# X--X No wineries found. Skipping Domaine Calvet-Thunevin,Côtes du Roussillon Villages,Languedoc-Roussillon,France...
#
# Searching for winery Nuiton-Beaunoy,Beaune,Burgundy,France
# ---> Nuiton-Beaunoy,Beaune,Burgundy,France appended
#
# Searching for winery Leeuwin Estate,Margaret River,Western Australia,Australia
# ---> Leeuwin Estate,Margaret River,Western Australia,Australia appended
#
# Searching for winery Terrabianca,Toscana,Tuscany,Italy
# X--X No wineries found. Skipping Terrabianca,Toscana,Tuscany,Italy...
#
# Searching for winery Yamhill Valley,McMinnville,Oregon,US
# ---> Yamhill Valley,McMinnville,Oregon,US appended
#
# Searching for winery Mayacamas,Mount Veeder,California,US
# ---> Mayacamas,Mount Veeder,California,US appended
#
# Searching for winery St. Innocent,Eola-Amity Hills,Oregon,US
# ---> St. Innocent,Eola-Amity Hills,Oregon,US appended
#
# Searching for winery Villa San Juliette,Paso Robles,California,US
# ---> Villa San Juliette,Paso Robles,California,US appended
#
# Searching for winery Corteforte,Amarone della Valpolicella Classico,Veneto,Italy
# X--X No wineries found. Skipping Corteforte,Amarone della Valpolicella Classico,Veneto,Italy...
#
# Searching for winery Big DeVine,Columbia Valley (WA),Washington,US
# ---> Big DeVine,Columbia Valley (WA),Washington,US appended
#
# Searching for winery Rodney Strong,Alexander Valley,California,US
# ---> Rodney Strong,Alexander Valley,California,US appended
#
# Searching for winery Woodward Canyon,Columbia Valley (WA),Washington,US
# ---> Woodward Canyon,Columbia Valley (WA),Washington,US appended
#
# Searching for winery Borjón,Amador County,California,US
# X--X No wineries found. Skipping Borjón,Amador County,California,US...
#
# Searching for winery Convento de Las Claras,Ribera del Duero,Northern Spain,Spain
# X--X No wineries found. Skipping Convento de Las Claras,Ribera del Duero,Northern Spain,Spain...
#
# Searching for winery Gianni Voerzio,Barolo,Piedmont,Italy
# ---> Gianni Voerzio,Barolo,Piedmont,Italy appended
#
# Searching for winery Marchesi de' Frescobaldi,Pomino,Tuscany,Italy
# ---> Marchesi de' Frescobaldi,Pomino,Tuscany,Italy appended
#
# Searching for winery Riscal,Vino de la Tierra de Castilla y León,Northern Spain,Spain
# X--X No wineries found. Skipping Riscal,Vino de la Tierra de Castilla y León,Northern Spain,Spain...
#
# Searching for winery Bosio,Barbaresco,Piedmont,Italy
# ---> Bosio,Barbaresco,Piedmont,Italy appended
#
# Searching for winery Nk'Mip Cellars,Okanagan Valley,British Columbia,Canada
# X--X No wineries found. Skipping Nk'Mip Cellars,Okanagan Valley,British Columbia,Canada...
#
# Searching for winery Paolo Scavino,Barolo,Piedmont,Italy
# ---> Paolo Scavino,Barolo,Piedmont,Italy appended

# %%
# Hit the OpenCageData API for each winery.
# Set up a Dictionary to hold reponse info for:
town=[]
lat=[]
lng=[]


print("Beginning search for nearby wineries... \n-----------------------------")

# Loop through the geo_test_pd and get a lat/long for each winery
for index, row in geo_test_pd.iterrows():
   
    query = f'{row["winery"]},{row["region_1"]},{row["province"]},{row["country"]}'
    place = urllib.parse.quote(query)
#     province = urllib.parse.quote(row["province"])
#     country = row["country"]

    base_url = (f'https://api.opencagedata.com/geocode/v1/json?q={place}&key={api_key}')

    try:
        print(f"Searching for winery: {query}")
        response = requests.get(base_url).json()
#         print(place)
#         print(province)
        
        # Selecting responses with medium to high confidence score
        num_responses = len(response['results'])
        print(f'num of responses {num_responses}')
        for x in range(num_responses):
            print(f'response{x}')
            confidence = response['results'][x]['confidence'] 
            if confidence >4:
                print(f'confidence:{confidence}')
                town.append(response['results'][x]['components']['town'])
                lat.append(response['results'][x]['geometry']['lat'])
                lng.append(response['results'][x]['geometry']['lng'])
                print(f'---> {query} appended')
                print(" ")
                break
            elif x == (num_responses - 1):
                print(f'Not confident: {confidence} - Skipping {query}...')
                print(" ")
                town.append(None)
                lat.append(None)
                lng.append(None)
            else:
                print(f'Not confident: {confidence} - Next result...')
                print(" ")
    except:
        print(f"X--X No wineries found. Skipping {query}...")
        print(" ")
        town.append(None)
        lat.append(None)
        lng.append(None)
# Out:
# Beginning search for nearby wineries...
# -----------------------------
# Searching for winery: Tamás,Central Coast,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# Not confident: 1 - Skipping Tamás,Central Coast,California,US...
#
# Searching for winery: Donum,Anderson Valley,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Donum,Anderson Valley,California,US...
#
# Searching for winery: Giacosa Fratelli,Barolo,Piedmont,Italy
# num of responses 1
# response0
# confidence:9
# ---> Giacosa Fratelli,Barolo,Piedmont,Italy appended
#
# Searching for winery: Dunning Vineyards,Paso Robles Willow Creek District,California,US
# num of responses 2
# response0
# confidence:5
# ---> Dunning Vineyards,Paso Robles Willow Creek District,California,US appended
#
# Searching for winery: Edna Valley Vineyard,Edna Valley,California,US
# num of responses 3
# response0
# confidence:9
# X--X No wineries found. Skipping Edna Valley Vineyard,Edna Valley,California,US...
#
# Searching for winery: Château Sainte Marie,Bordeaux Supérieur,Bordeaux,France
# num of responses 6
# response0
# confidence:7
# ---> Château Sainte Marie,Bordeaux Supérieur,Bordeaux,France appended
#
# Searching for winery: Chateau Ste. Michelle,Horse Heaven Hills,Washington,US
# num of responses 1
# response0
# confidence:9
# X--X No wineries found. Skipping Chateau Ste. Michelle,Horse Heaven Hills,Washington,US...
#
# Searching for winery: Casanel,Middleburg,Virginia,US
# num of responses 1
# response0
# confidence:7
# ---> Casanel,Middleburg,Virginia,US appended
#
# Searching for winery: Bella Luna,San Benito County,California,US
# num of responses 2
# response0
# confidence:5
# ---> Bella Luna,San Benito County,California,US appended
#
# Searching for winery: Tenute Mater Domini,Salento,Southern Italy,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Tenute Mater Domini,Salento,Southern Italy,Italy...
#
# Searching for winery: Arrogant Frog,Pays d'Oc,Languedoc-Roussillon,France
# num of responses 10
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 2 - Next result...
#
# response2
# Not confident: 2 - Next result...
#
# response3
# Not confident: 2 - Next result...
#
# response4
# Not confident: 2 - Next result...
#
# response5
# Not confident: 2 - Next result...
#
# response6
# Not confident: 2 - Next result...
#
# response7
# Not confident: 2 - Next result...
#
# response8
# confidence:10
# X--X No wineries found. Skipping Arrogant Frog,Pays d'Oc,Languedoc-Roussillon,France...
#
# Searching for winery: PianCornello,Brunello di Montalcino,Tuscany,Italy
# num of responses 1
# response0
# confidence:8
# ---> PianCornello,Brunello di Montalcino,Tuscany,Italy appended
#
# Searching for winery: Díaz Bayo,Ribera del Duero,Northern Spain,Spain
# num of responses 1
# response0
# Not confident: 1 - Skipping Díaz Bayo,Ribera del Duero,Northern Spain,Spain...
#
# Searching for winery: Jean-Luc Baldès,Cahors,Southwest France,France
# num of responses 6
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 2 - Next result...
#
# response2
# Not confident: 2 - Next result...
#
# response3
# Not confident: 2 - Next result...
#
# response4
# Not confident: 2 - Next result...
#
# response5
# confidence:10
# X--X No wineries found. Skipping Jean-Luc Baldès,Cahors,Southwest France,France...
#
# Searching for winery: Fattoria La Rivolta,Sannio,Southern Italy,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Fattoria La Rivolta,Sannio,Southern Italy,Italy...
#
# Searching for winery: Three Rivers,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Three Rivers,Columbia Valley (WA),Washington,US...
#
# Searching for winery: Brick & Mortar,Sonoma Coast,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Brick & Mortar,Sonoma Coast,California,US...
#
# Searching for winery: Anthony Road,Finger Lakes,New York,US
# num of responses 2
# response0
# confidence:7
# ---> Anthony Road,Finger Lakes,New York,US appended
#
# Searching for winery: Talbott,Monterey,California,US
# num of responses 3
# response0
# confidence:9
# X--X No wineries found. Skipping Talbott,Monterey,California,US...
#
# Searching for winery: Primosic,Collio,Northeastern Italy,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Primosic,Collio,Northeastern Italy,Italy...
#
# Searching for winery: Wellington,Sonoma Valley,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Wellington,Sonoma Valley,California,US...
#
# Searching for winery: Taz,Santa Barbara County,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Taz,Santa Barbara County,California,US...
#
# Searching for winery: Ocaso,Mendoza,Mendoza Province,Argentina
# num of responses 1
# response0
# Not confident: 1 - Skipping Ocaso,Mendoza,Mendoza Province,Argentina...
#
# Searching for winery: Mas de Cadenet,Côtes de Provence,Provence,France
# num of responses 8
# response0
# confidence:9
# X--X No wineries found. Skipping Mas de Cadenet,Côtes de Provence,Provence,France...
#
# Searching for winery: Talamonti,Montepulciano d'Abruzzo,Central Italy,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Talamonti,Montepulciano d'Abruzzo,Central Italy,Italy...
#
# Searching for winery: Channing Daughters,North Fork of Long Island,New York,US
# num of responses 2
# response0
# confidence:5
# ---> Channing Daughters,North Fork of Long Island,New York,US appended
#
# Searching for winery: Cave de Cleebourg,Crémant d'Alsace,Alsace,France
# num of responses 3
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 2 - Next result...
#
# response2
# confidence:10
# X--X No wineries found. Skipping Cave de Cleebourg,Crémant d'Alsace,Alsace,France...
#
# Searching for winery: Bergström,Willamette Valley,Oregon,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Bergström,Willamette Valley,Oregon,US...
#
# Searching for winery: Alice White,South Eastern Australia,Australia Other,Australia
# num of responses 2
# response0
# confidence:10
# X--X No wineries found. Skipping Alice White,South Eastern Australia,Australia Other,Australia...
#
# Searching for winery: Château du Cros,Cadillac Côtes de Bordeaux,Bordeaux,France
# num of responses 2
# response0
# confidence:7
# ---> Château du Cros,Cadillac Côtes de Bordeaux,Bordeaux,France appended
#
# Searching for winery: Bodegas Mähler-Besse,Jumilla,Levante,Spain
# num of responses 1
# response0
# confidence:9
# X--X No wineries found. Skipping Bodegas Mähler-Besse,Jumilla,Levante,Spain...
#
# Searching for winery: Von Holt,Russian River Valley,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Von Holt,Russian River Valley,California,US...
#
# Searching for winery: Sol Rouge,Red Hills Lake County,California,US
# num of responses 2
# response0
# confidence:5
# ---> Sol Rouge,Red Hills Lake County,California,US appended
#
# Searching for winery: Efeste,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Efeste,Columbia Valley (WA),Washington,US...
#
# Searching for winery: PerryMoore,Napa Valley,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping PerryMoore,Napa Valley,California,US...
#
# Searching for winery: El Coto,Rioja,Northern Spain,Spain
# num of responses 1
# response0
# Not confident: 1 - Skipping El Coto,Rioja,Northern Spain,Spain...
#
# Searching for winery: Stinson,Monticello,Virginia,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Stinson,Monticello,Virginia,US...
#
# Searching for winery: Alain Jaume et Fils,Gigondas,Rhône Valley,France
# num of responses 4
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 2 - Next result...
#
# response2
# Not confident: 2 - Next result...
#
# response3
# Not confident: 2 - Skipping Alain Jaume et Fils,Gigondas,Rhône Valley,France...
#
# Searching for winery: Airfield Estates,Yakima Valley,Washington,US
# num of responses 2
# response0
# confidence:6
# ---> Airfield Estates,Yakima Valley,Washington,US appended
#
# Searching for winery: Château Bellevue de Tayac,Margaux,Bordeaux,France
# num of responses 10
# response0
# confidence:7
# ---> Château Bellevue de Tayac,Margaux,Bordeaux,France appended
#
# Searching for winery: Planeta,Sicilia,Sicily & Sardinia,Italy
# num of responses 1
# response0
# confidence:9
# X--X No wineries found. Skipping Planeta,Sicilia,Sicily & Sardinia,Italy...
#
# Searching for winery: àMaurice,Walla Walla Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping àMaurice,Walla Walla Valley (WA),Washington,US...
#
# Searching for winery: Domaine Jacques Prieur,Volnay,Burgundy,France
# num of responses 1
# response0
# confidence:9
# ---> Domaine Jacques Prieur,Volnay,Burgundy,France appended
#
# Searching for winery: Roblar,Sta. Rita Hills,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Roblar,Sta. Rita Hills,California,US...
#
# Searching for winery: Allegrini,Veronese,Veneto,Italy
# num of responses 1
# response0
# confidence:9
# ---> Allegrini,Veronese,Veneto,Italy appended
#
# Searching for winery: Rieflé,Alsace,Alsace,France
# num of responses 2
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 3 - Skipping Rieflé,Alsace,Alsace,France...
#
# Searching for winery: Sineann,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Sineann,Columbia Valley (WA),Washington,US...
#
# Searching for winery: Kali Hart,Monterey County,California,US
# num of responses 2
# response0
# confidence:5
# ---> Kali Hart,Monterey County,California,US appended
#
# Searching for winery: Pessagno,Santa Lucia Highlands,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:7
# ---> Pessagno,Santa Lucia Highlands,California,US appended
#
# Searching for winery: Domaine Coquard Loisson-Fleurot,Echézeaux,Burgundy,France
# num of responses 4
# response0
# confidence:9
# X--X No wineries found. Skipping Domaine Coquard Loisson-Fleurot,Echézeaux,Burgundy,France...
#
# Searching for winery: Calera,Mt. Harlan,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Calera,Mt. Harlan,California,US...
#
# Searching for winery: Novy,Russian River Valley,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Novy,Russian River Valley,California,US...
#
# Searching for winery: Chavet Fils,Menetou-Salon,Loire Valley,France
# num of responses 10
# response0
# confidence:9
# X--X No wineries found. Skipping Chavet Fils,Menetou-Salon,Loire Valley,France...
#
# Searching for winery: Fidelitas,Red Mountain,Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Fidelitas,Red Mountain,Washington,US...
#
# Searching for winery: Ott & Murphy,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Ott & Murphy,Columbia Valley (WA),Washington,US...
#
# Searching for winery: Nera,Sforzato di Valtellina,Lombardy,Italy
# num of responses 1
# response0
# confidence:9
# X--X No wineries found. Skipping Nera,Sforzato di Valtellina,Lombardy,Italy...
#
# Searching for winery: Heron Hill,Finger Lakes,New York,US
# num of responses 2
# response0
# confidence:5
# ---> Heron Hill,Finger Lakes,New York,US appended
#
# Searching for winery: Tin Barn,Carneros,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Tin Barn,Carneros,California,US...
#
# Searching for winery: Rochioli,Russian River Valley,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Rochioli,Russian River Valley,California,US...
#
# Searching for winery: MCV,Paso Robles,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:6
# ---> MCV,Paso Robles,California,US appended
#
# Searching for winery: Kevin White,Yakima Valley,Washington,US
# num of responses 2
# response0
# confidence:6
# ---> Kevin White,Yakima Valley,Washington,US appended
#
# Searching for winery: Gray Ghost,Virginia,Virginia,US
# num of responses 1
# response0
# Not confident: 1 - Skipping Gray Ghost,Virginia,Virginia,US...
#
# Searching for winery: Novy,Santa Lucia Highlands,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:7
# ---> Novy,Santa Lucia Highlands,California,US appended
#
# Searching for winery: Château de Seguin,Bordeaux,Bordeaux,France
# num of responses 10
# response0
# confidence:8
# X--X No wineries found. Skipping Château de Seguin,Bordeaux,Bordeaux,France...
#
# Searching for winery: Bouchard Père & Fils,Corton,Burgundy,France
# num of responses 10
# response0
# confidence:9
# X--X No wineries found. Skipping Bouchard Père & Fils,Corton,Burgundy,France...
#
# Searching for winery: Gustave Lorentz,Crémant d'Alsace,Alsace,France
# num of responses 3
# response0
# Not confident: 1 - Next result...
#
# response1
# Not confident: 3 - Next result...
#
# response2
# Not confident: 3 - Skipping Gustave Lorentz,Crémant d'Alsace,Alsace,France...
#
# Searching for winery: El Grifo,Lanzarote,Spanish Islands,Spain
# num of responses 1
# response0
# Not confident: 1 - Skipping El Grifo,Lanzarote,Spanish Islands,Spain...
#
# Searching for winery: Blackbird Vineyards,Napa Valley,California,US
# num of responses 2
# response0
# confidence:6
# ---> Blackbird Vineyards,Napa Valley,California,US appended
#
# Searching for winery: Langtry,Guenoc Valley,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 1 - Skipping Langtry,Guenoc Valley,California,US...
#
# Searching for winery: Shalestone,Finger Lakes,New York,US
# num of responses 2
# response0
# Not confident: 2 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Shalestone,Finger Lakes,New York,US...
#
# Searching for winery: Petroni,Sonoma Valley,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Petroni,Sonoma Valley,California,US...
#
# Searching for winery: August Truth,Mendocino Ridge,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:7
# ---> August Truth,Mendocino Ridge,California,US appended
#
# Searching for winery: Lange,Willamette Valley,Oregon,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Lange,Willamette Valley,Oregon,US...
#
# Searching for winery: Charles Fournier,Finger Lakes,New York,US
# num of responses 2
# response0
# confidence:5
# ---> Charles Fournier,Finger Lakes,New York,US appended
#
# Searching for winery: Kirkland Signature,Châteauneuf-du-Pape,Rhône Valley,France
# num of responses 1
# response0
# Not confident: 1 - Skipping Kirkland Signature,Châteauneuf-du-Pape,Rhône Valley,France...
#
# Searching for winery: Bricco dei Guazzi,Barbera del Monferrato,Piedmont,Italy
# num of responses 1
# response0
# confidence:7
# ---> Bricco dei Guazzi,Barbera del Monferrato,Piedmont,Italy appended
#
# Searching for winery: Bianchi,Paso Robles,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:6
# ---> Bianchi,Paso Robles,California,US appended
#
# Searching for winery: Thousand Islands Winery,New York,New York,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# Not confident: 2 - Skipping Thousand Islands Winery,New York,New York,US...
#
# Searching for winery: Josef Weger,Alto Adige,Northeastern Italy,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Josef Weger,Alto Adige,Northeastern Italy,Italy...
#
# Searching for winery: Maximo,Vino de la Tierra de Castilla,Central Spain,Spain
# num of responses 1
# response0
# confidence:9
# ---> Maximo,Vino de la Tierra de Castilla,Central Spain,Spain appended
#
# Searching for winery: Domaine Calvet-Thunevin,Côtes du Roussillon Villages,Languedoc-Roussillon,France
# num of responses 1
# response0
# Not confident: 1 - Skipping Domaine Calvet-Thunevin,Côtes du Roussillon Villages,Languedoc-Roussillon,France...
#
# Searching for winery: Nuiton-Beaunoy,Beaune,Burgundy,France
# num of responses 2
# response0
# confidence:7
# ---> Nuiton-Beaunoy,Beaune,Burgundy,France appended
#
# Searching for winery: Leeuwin Estate,Margaret River,Western Australia,Australia
# num of responses 4
# response0
# confidence:9
# ---> Leeuwin Estate,Margaret River,Western Australia,Australia appended
#
# Searching for winery: Terrabianca,Toscana,Tuscany,Italy
# num of responses 2
# response0
# confidence:8
# X--X No wineries found. Skipping Terrabianca,Toscana,Tuscany,Italy...
#
# Searching for winery: Yamhill Valley,McMinnville,Oregon,US
# num of responses 10
# response0
# confidence:9
# ---> Yamhill Valley,McMinnville,Oregon,US appended
#
# Searching for winery: Mayacamas,Mount Veeder,California,US
# num of responses 2
# response0
# confidence:6
# ---> Mayacamas,Mount Veeder,California,US appended
#
# Searching for winery: St. Innocent,Eola-Amity Hills,Oregon,US
# num of responses 2
# response0
# confidence:5
# ---> St. Innocent,Eola-Amity Hills,Oregon,US appended
#
# Searching for winery: Villa San Juliette,Paso Robles,California,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:6
# ---> Villa San Juliette,Paso Robles,California,US appended
#
# Searching for winery: Corteforte,Amarone della Valpolicella Classico,Veneto,Italy
# num of responses 1
# response0
# Not confident: 1 - Skipping Corteforte,Amarone della Valpolicella Classico,Veneto,Italy...
#
# Searching for winery: Big DeVine,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 4 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Big DeVine,Columbia Valley (WA),Washington,US...
#
# Searching for winery: Rodney Strong,Alexander Valley,California,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:7
# X--X No wineries found. Skipping Rodney Strong,Alexander Valley,California,US...
#
# Searching for winery: Woodward Canyon,Columbia Valley (WA),Washington,US
# num of responses 2
# response0
# Not confident: 3 - Next result...
#
# response1
# confidence:9
# X--X No wineries found. Skipping Woodward Canyon,Columbia Valley (WA),Washington,US...
#
# Searching for winery: Borjón,Amador County,California,US
# num of responses 3
# response0
# confidence:9
# X--X No wineries found. Skipping Borjón,Amador County,California,US...
#
# Searching for winery: Convento de Las Claras,Ribera del Duero,Northern Spain,Spain
# num of responses 1
# response0
# Not confident: 1 - Skipping Convento de Las Claras,Ribera del Duero,Northern Spain,Spain...
#
# Searching for winery: Gianni Voerzio,Barolo,Piedmont,Italy
# num of responses 1
# response0
# confidence:9
# ---> Gianni Voerzio,Barolo,Piedmont,Italy appended
#
# Searching for winery: Marchesi de' Frescobaldi,Pomino,Tuscany,Italy
# num of responses 1
# response0
# confidence:8
# ---> Marchesi de' Frescobaldi,Pomino,Tuscany,Italy appended
#
# Searching for winery: Riscal,Vino de la Tierra de Castilla y León,Northern Spain,Spain
# num of responses 1
# response0
# Not confident: 1 - Skipping Riscal,Vino de la Tierra de Castilla y León,Northern Spain,Spain...
#
# Searching for winery: Bosio,Barbaresco,Piedmont,Italy
# num of responses 1
# response0
# confidence:8
# ---> Bosio,Barbaresco,Piedmont,Italy appended
#
# Searching for winery: Nk'Mip Cellars,Okanagan Valley,British Columbia,Canada
# num of responses 2
# response0
# confidence:9
# X--X No wineries found. Skipping Nk'Mip Cellars,Okanagan Valley,British Columbia,Canada...
#
# Searching for winery: Paolo Scavino,Barolo,Piedmont,Italy
# num of responses 1
# response0
# confidence:9
# ---> Paolo Scavino,Barolo,Piedmont,Italy appended

# %%
town, lat, lng
len(town)
# Out:
# 100

# %%
# Store the highest confidence result into the DataFrame.
geo_test_pd['town'] = town
geo_test_pd['lat'] = lat
geo_test_pd['lng'] = lng
geo_test_pd2 = geo_test_pd.dropna(subset=['lat', 'lng'])
geo_test_pd2
# Out:
#       country                                        description  \
# 2       Italy  This is a sharply focused expression of the Bu...
# 3          US  Incredibly rich blackberry-jam aromas meet wit...
# 5      France  Ripe and toasty, this is a rich, full-bodied a...
# 7          US  Lush black plum, bramble and black pepper ming...
# 8          US  Restrained aromatically, this bottling shows t...
# 11      Italy  A steady protagonist in the greater Brunello f...
# 17         US  Pristine white grapefruit and pear are accente...
# 25         US  Each of Channing Daughter's eight 2011 vintage...
# 29     France  Structured and firm, with dense, dry tannins, ...
# 32         US  Abundant dark fruit flavors, particularly Bing...
# 38         US  Merlot (73%) takes the lead on this wine, whic...
# 39     France  The small 11-acre estate is situated at the no...
# 42     France  Rich, opulent and spicy, with a great balance ...
# 44      Italy  Made from a blend of Corvina, Syrah and Oselet...
# 47         US  This is a sort of second tier wine from Talbot...
# 48         US  Fig, black plum, dried cherry and chai spice s...
# 56         US  Spice notes accent pressed-apple aromas on thi...
# 59         US  Yellow peach, lemon, Asian pear and citrus pee...
# 60         US  Hailing from Olsen and Elephant Mountain viney...
# 62         US  Some wineries releasing a new Garys' Syrah wou...
# 67         US  So soft and dense in richness, this is easy to...
# 71         US  A dark color and candied, pruney aromas give w...
# 73         US  Hints of earth and spice accent savory apple a...
# 75      Italy  Here's a simpatico Barbera from Monferrato wit...
# 76         US  Soft, sweet and a little hot, this has flavors...
# 79      Spain  Mealy aromas of compostable white fruits lack ...
# 81     France  This is a smooth wine with gentle tannins and ...
# 82  Australia  The Art Series Cabernet seems to be increasing...
# 84         US  This has a noticeable scent of tackroom leathe...
# 85         US  Lean, dry and minerally, with tart flavors of ...
# 86         US  Theoretically a very light rosé, the “Eye of t...
# 87         US  This top-shelf red blend from television produ...
# 94      Italy  A stunning wine with amazing intensity and a v...
# 95      Italy  This barrique-aged Chardonnay opens with delic...
# 97      Italy  This is aged for two years in French oak to sh...
# 99      Italy  Red rose, mature wild berry, dark cooking spic...
#
#                         designation  points  price           province  \
# 2                            Bussia      91   52.0           Piedmont
# 3                               NaN      93   42.0         California
# 5                               NaN      90   15.0           Bordeaux
# 7                            Estate      87   34.0           Virginia
# 8                            Grosso      85   45.0         California
# 11                              NaN      89   70.0            Tuscany
# 17                              NaN      87   17.0           New York
# 25      Rosato Merlot Mudd Vineyard      90   18.0           New York
# 29                              NaN      88   18.0           Bordeaux
# 32                              NaN      91   39.0         California
# 38                        Dauntless      90   18.0         Washington
# 39                              NaN      92   35.0           Bordeaux
# 42                         Champans      93  138.0           Burgundy
# 44                         La Grola      89   32.0             Veneto
# 47                              NaN      90   19.0         California
# 48                              NaN      88   42.0         California
# 56                   Ingle Vineyard      87   20.0           New York
# 59                              NaN      89   30.0         California
# 60                       En Hommage      90   28.0         Washington
# 62                  Garys' Vineyard      90   32.0         California
# 67                       Contrarian      94  125.0         California
# 71        Manchester Ridge Vineyard      84   42.0         California
# 73              Gold Seal Vineyards      82   16.0           New York
# 75                              NaN      87   24.0           Piedmont
# 76              Signature Selection      86   19.0         California
# 79                 Edicion Limitada      82    9.0      Central Spain
# 81                              NaN      87   32.0           Burgundy
# 82                       Art Series      92   60.0  Western Australia
# 84                           Estate      87   22.0             Oregon
# 85                              NaN      88   40.0         California
# 86  Zenith Vineyard Oeil de Perdrix      91   20.0             Oregon
# 87               Romantique Reserve      91   60.0         California
# 94                         La Serra      96  125.0           Piedmont
# 95                Benefizio Riserva      89   45.0            Tuscany
# 97                              NaN      89   32.0           Piedmont
# 99   Rocche dell'Annunziata Riserva      94  180.0           Piedmont
#
#                              region_1           region_2  \
# 2                              Barolo                NaN
# 3   Paso Robles Willow Creek District      Central Coast
# 5                  Bordeaux Supérieur                NaN
# 7                          Middleburg                NaN
# 8                   San Benito County      Central Coast
# 11             Brunello di Montalcino                NaN
# 17                       Finger Lakes       Finger Lakes
# 25          North Fork of Long Island        Long Island
# 29         Cadillac Côtes de Bordeaux                NaN
# 32              Red Hills Lake County                NaN
# 38                      Yakima Valley    Columbia Valley
# 39                            Margaux                NaN
# 42                             Volnay                NaN
# 44                           Veronese                NaN
# 47                    Monterey County      Central Coast
# 48              Santa Lucia Highlands      Central Coast
# 56                       Finger Lakes       Finger Lakes
# 59                        Paso Robles      Central Coast
# 60                      Yakima Valley    Columbia Valley
# 62              Santa Lucia Highlands      Central Coast
# 67                        Napa Valley               Napa
# 71                    Mendocino Ridge                NaN
# 73                       Finger Lakes       Finger Lakes
# 75             Barbera del Monferrato                NaN
# 76                        Paso Robles      Central Coast
# 79      Vino de la Tierra de Castilla                NaN
# 81                             Beaune                NaN
# 82                     Margaret River                NaN
# 84                        McMinnville  Willamette Valley
# 85                       Mount Veeder               Napa
# 86                   Eola-Amity Hills  Willamette Valley
# 87                        Paso Robles      Central Coast
# 94                             Barolo                NaN
# 95                             Pomino                NaN
# 97                         Barbaresco                NaN
# 99                             Barolo                NaN
#
#                                                 title  \
# 2              Giacosa Fratelli 2004 Bussia  (Barolo)
# 3   Dunning Vineyards 2013 Cabernet Sauvignon (Pas...
# 5       Château Sainte Marie 2011  Bordeaux Supérieur
# 7   Casanel 2014 Estate Cabernet Sauvignon (Middle...
# 8   Bella Luna 2012 Grosso Sangiovese (San Benito ...
# 11          PianCornello 2008  Brunello di Montalcino
# 17        Anthony Road 2016 Pinot Gris (Finger Lakes)
# 25  Channing Daughters 2011 Rosato Merlot Mudd Vin...
# 29   Château du Cros 2015  Cadillac Côtes de Bordeaux
# 32  Sol Rouge 2013 Cabernet Sauvignon (Red Hills L...
# 38  Airfield Estates 2014 Dauntless Red (Yakima Va...
# 39            Château Bellevue de Tayac 2014  Margaux
# 42     Domaine Jacques Prieur 2009 Champans  (Volnay)
# 44             Allegrini 2010 La Grola Red (Veronese)
# 47        Kali Hart 2007 Chardonnay (Monterey County)
# 48   Pessagno 2013 Pinot Noir (Santa Lucia Highlands)
# 56  Heron Hill 2011 Ingle Vineyard Riesling (Finge...
# 59                    MCV 2016 Viognier (Paso Robles)
# 60  Kevin White 2013 En Hommage Syrah (Yakima Valley)
# 62  Novy 2011 Garys' Vineyard Syrah (Santa Lucia H...
# 67  Blackbird Vineyards 2010 Contrarian Red (Napa ...
# 71  August Truth 2012 Manchester Ridge Vineyard Pi...
# 73  Charles Fournier 2012 Gold Seal Vineyards Ries...
# 75     Bricco dei Guazzi 2007  Barbera del Monferrato
# 76  Bianchi 2008 Signature Selection Cabernet Fran...
# 79  Maximo 2013 Edicion Limitada Viura (Vino de la...
# 81                        Nuiton-Beaunoy 2015  Beaune
# 82  Leeuwin Estate 2012 Art Series Cabernet Sauvig...
# 84  Yamhill Valley 2014 Estate Pinot Noir (McMinnv...
# 85           Mayacamas 2010 Chardonnay (Mount Veeder)
# 86  St. Innocent 2015 Zenith Vineyard Oeil de Perd...
# 87  Villa San Juliette 2013 Romantique Reserve Red...
# 94             Gianni Voerzio 2007 La Serra  (Barolo)
# 95  Marchesi de' Frescobaldi 2012 Benefizio Riserv...
# 97                             Bosio 2007  Barbaresco
# 99  Paolo Scavino 2009 Rocche dell'Annunziata Rise...
#
#                      variety                     winery              town  \
# 2                   Nebbiolo           Giacosa Fratelli            Barolo
# 3         Cabernet Sauvignon          Dunning Vineyards   Santa Margarita
# 5   Bordeaux-style Red Blend       Château Sainte Marie          Bordeaux
# 7         Cabernet Sauvignon                    Casanel        Middleburg
# 8                 Sangiovese                 Bella Luna   California City
# 11         Sangiovese Grosso               PianCornello        Montalcino
# 17                Pinot Gris               Anthony Road          Penn Yan
# 25                      Rosé         Channing Daughters          New York
# 29  Bordeaux-style Red Blend            Château du Cros          Bordeaux
# 32        Cabernet Sauvignon                  Sol Rouge   California City
# 38  Bordeaux-style Red Blend           Airfield Estates            Yakima
# 39  Bordeaux-style Red Blend  Château Bellevue de Tayac          Bordeaux
# 42                Pinot Noir     Domaine Jacques Prieur            Volnay
# 44                 Red Blend                  Allegrini          Veronese
# 47                Chardonnay                  Kali Hart           Montara
# 48                Pinot Noir                   Pessagno         Highlands
# 56                  Riesling                 Heron Hill      Mount Morris
# 59                  Viognier                        MCV       Paso Robles
# 60                     Syrah                Kevin White            Yakima
# 62                     Syrah                       Novy         Highlands
# 67  Bordeaux-style Red Blend        Blackbird Vineyards   California City
# 71                Pinot Noir               August Truth             Ridge
# 73                  Riesling           Charles Fournier          New York
# 75                   Barbera          Bricco dei Guazzi  Nizza Monferrato
# 76            Cabernet Franc                    Bianchi       Paso Robles
# 79                     Viura                     Maximo           Central
# 81                Pinot Noir             Nuiton-Beaunoy            Beaune
# 82        Cabernet Sauvignon             Leeuwin Estate       Witchcliffe
# 84                Pinot Noir             Yamhill Valley       McMinnville
# 85                Chardonnay                  Mayacamas          Corcoran
# 86                Pinot Noir               St. Innocent      Independence
# 87                 Red Blend         Villa San Juliette       Paso Robles
# 94                  Nebbiolo             Gianni Voerzio            Barolo
# 95                Chardonnay   Marchesi de' Frescobaldi            Pomino
# 97                  Nebbiolo                      Bosio        Barbaresco
# 99                  Nebbiolo              Paolo Scavino            Barolo
#
#           lat         lng
# 2   44.610940    7.942840
# 3   35.303644 -120.373697
# 5   44.840440   -0.580500
# 7   38.998822  -77.733937
# 8   35.133219 -117.962699
# 11  43.053970   11.488530
# 17  42.705788  -76.975276
# 25  40.799948  -73.951190
# 29  44.840440   -0.580500
# 32  35.130657 -117.937412
# 38  46.547726 -120.476597
# 39  44.840440   -0.580500
# 42  47.001070    4.781790
# 44  45.185460   11.606740
# 47  37.539560 -122.507700
# 48  37.519940 -122.343860
# 56  42.727035  -77.880866
# 59  35.626640 -120.691000
# 60  46.547726 -120.476597
# 62  37.519940 -122.343860
# 67  35.113893 -117.982087
# 71  39.336550 -123.301120
# 73  40.734477  -74.008462
# 75  44.774160    8.357840
# 76  35.626640 -120.691000
# 79  42.467210    0.991170
# 81  47.033330    4.833330
# 82 -34.013371  115.065606
# 84  45.215486 -123.168550
# 85  35.418252 -119.127026
# 86  44.867078 -123.192042
# 87  35.626640 -120.691000
# 94  44.610940    7.942840
# 95  43.817810   11.547830
# 97  44.723240    8.081940
# 99  44.610940    7.942840

# %%
len(geo_test_pd2)
# Out:
# 36

# %%
geo_test_pd2.to_csv('../Resources/geo_test2.csv', encoding='utf-8')

# %%
## If closing Jupyter Notebook, read in the saved geo_test2.csv instead of re-reunning OpenCageData API calls
geo_test_pd2 = pd.read_csv('../Resources/geo_test2.csv', encoding='utf-8')

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'lat' and 'lng' into  locations 
locations = geo_test_pd2[["lat", "lng"]].astype(float)
# locations
rating = geo_test_pd2["points"].astype(float)
price = geo_test_pd2["price"].astype(float)

# Create Humidity Heatmap layer
fig = gmaps.figure()

heat_rating = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=True, max_intensity=rating.max())
heat_price = gmaps.heatmap_layer(locations, weights=price, 
                                 dissipating=True, max_intensity=price.max(), opacity=0.3, gradient=['blue','red'])

fig.add_layer(heat_rating)
fig.add_layer(heat_price)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{winery}</dd>
<dt>Vintage</dt><dd>{title}</dd>
<dt>Rating</dt><dd>{points}</dd>
<dt>Price</dt><dd>{price}</dd>
<dt>Province</dt><dd>{province}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
winery_info = [info_box_template.format(**row) for index, row in geo_test_pd2.iterrows()]
locations = geo_test_pd2[["lat", "lng"]]

# %%
# Add marker layer ontop of heat map
fig = gmaps.figure()

# rating = geo_test_pd2['points']

# def color(rating): 
#     if rating in range(95,100): 
#         col = 'blue'
#     elif rating in range(90,94): 
#         col = 'green'
#     elif rating in range(80,89): 
#         col = 'orange'
#     else: 
#         col='red'
#     return col 

marker_layer = gmaps.marker_layer(locations, info_box_content=winery_info, display_info_box=None)
# marker_layer.markers[0].label = 'C'  # markers[0].label changes the center of the red Google Marker

# wine_rating_layer = gmaps.symbol_layer(locations, fill_color=color(rating),stroke_color="black", scale=5)


# fid.add_layer(wine_rating_layer)
fig.add_layer(heat_rating)
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Other APIs tried

# %%
# # Set parameters to search for locations within 5000 meters.
# # geocoordinates
# target_coordinates = "34.01,-118.81"
# target_search = "wine"
# target_radius = 5000
# target_type = "winery"

# # set up a parameters dictionary
# params = {
#     "location": target_coordinates,
#     "keyword": target_search,
#     "radius": target_radius,
#     "type": target_type,
#     "key": g_key}

# # base url
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# # run a request using our params dictionary
# response = requests.get(base_url, params=params).json()
# pprint.pprint(response)

# %%
# # Set parameters to Text Search search for winery locations.

# target_search = "Rainstorm+winery"
# target_type = "winery"

# # set up a parameters dictionary
# params = {
#     "query": target_search,
#     "type": target_type,
#     "key": g_key}

# # base url
# base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

# # run a request using our params dictionary
# response = requests.get(base_url, params=params).json()
# pprint.pprint(response)

# %%
# # Set parameters Find Place From Text to search for winery locations.

# target_search = "Rainstorm"
# target_type = "winery,wine"

# # set up a parameters dictionary
# params = {
#     "input": target_search,
#     "inputtype": "textquery",
#     "type": target_type,
#     "key": g_key}

# # base url
# base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

# # run a request using our params dictionary
# response = requests.get(base_url, params=params).json()
# pprint.pprint(response)
