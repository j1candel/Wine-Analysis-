# %%
#Import Modules 
import os 
import csv 
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np

# %%
#Open Wine File 
csv_path = '../Resources/winemag-data.csv'

# %%
#Read wine data 
wine_data_pd = pd.read_csv(csv_path)

#Cleaning Data 
clean_data_pd = wine_data_pd.drop(['taster_name', 'taster_twitter_handle'], axis=1)
clean_data_pd = clean_data_pd.dropna(subset=['price', 'region_1'])

# %%
clean_data_pd.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 2           2      US  Tart and snappy, the flavors of lime flesh and...
# 3           3      US  Pineapple rind, lemon pith and orange blossom ...
# 4           4      US  Much like the regular bottling from 2012, this...
# 5           5   Spain  Blackberry and raspberry aromas show a typical...
# 6           6   Italy  Here's a bright, informal red that opens with ...
#
#                           designation  points  price           province  \
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
#
#               region_1           region_2  \
# 2    Willamette Valley  Willamette Valley
# 3  Lake Michigan Shore                NaN
# 4    Willamette Valley  Willamette Valley
# 5              Navarra                NaN
# 6             Vittoria                NaN
#
#                                                title             variety  \
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
#
#             winery
# 2        Rainstorm
# 3       St. Julian
# 4     Sweet Cheeks
# 5           Tandem
# 6  Terre di Giurfo

# %%
clean_data_pd.loc[clean_data_pd['winery'] == 'Baricci']
# Out:
#         Unnamed: 0 country                                        description  \
# 13132        13132   Italy  Enticing, classic Sangiovese aromas of fragran...
# 21252        21252   Italy  The wine is subdued and clean on the nose and ...
# 40813        40813   Italy  Pretty aromas of underbrush, crushed blue flow...
# 45783        45783   Italy  New leather, mature black-skinned fruit, tille...
# 52452        52452   Italy  Pretty aromas of underbrush, crushed blue flow...
# 59976        59976   Italy  Enticing perfumed berry, violet, new leather a...
# 60746        60746   Italy  The wine is subdued and clean on the nose and ...
# 116745      116745   Italy  Enticing, classic Sangiovese aromas of fragran...
# 117605      117605   Italy  Aromas suggesting underbrush, scorched earth, ...
#
#           designation  points  price province                region_1  \
# 13132             NaN      89   20.0  Tuscany     Rosso di Montalcino
# 21252             NaN      89   40.0  Tuscany  Brunello di Montalcino
# 40813             NaN      90   18.0  Tuscany     Rosso di Montalcino
# 45783   Nello Riserva      98  120.0  Tuscany  Brunello di Montalcino
# 52452             NaN      90   18.0  Tuscany     Rosso di Montalcino
# 59976             NaN      96   50.0  Tuscany  Brunello di Montalcino
# 60746             NaN      89   40.0  Tuscany  Brunello di Montalcino
# 116745            NaN      89   20.0  Tuscany     Rosso di Montalcino
# 117605            NaN      94   50.0  Tuscany  Brunello di Montalcino
#
#        region_2                                              title  \
# 13132       NaN                  Baricci 2014  Rosso di Montalcino
# 21252       NaN               Baricci 2007  Brunello di Montalcino
# 40813       NaN                  Baricci 2012  Rosso di Montalcino
# 45783       NaN  Baricci 2010 Nello Riserva  (Brunello di Monta...
# 52452       NaN                  Baricci 2012  Rosso di Montalcino
# 59976       NaN               Baricci 2012  Brunello di Montalcino
# 60746       NaN               Baricci 2007  Brunello di Montalcino
# 116745      NaN                  Baricci 2014  Rosso di Montalcino
# 117605      NaN               Baricci 2011  Brunello di Montalcino
#
#                   variety   winery
# 13132          Sangiovese  Baricci
# 21252   Sangiovese Grosso  Baricci
# 40813          Sangiovese  Baricci
# 45783          Sangiovese  Baricci
# 52452          Sangiovese  Baricci
# 59976          Sangiovese  Baricci
# 60746   Sangiovese Grosso  Baricci
# 116745         Sangiovese  Baricci
# 117605         Sangiovese  Baricci

# %%
# Creating the test dataset
# geo_test_pd = clean_data_pd.sample(100)
# geo_test_pd

# %%
# geo_test_pd.to_csv('../Resources/geo_test100.csv', encoding='utf-8')

# %%
# Createing the FINAL dataset
map_sample_pd = clean_data_pd.sample(1000)
map_sample_pd
# Out:
#         Unnamed: 0    country  \
# 58932        58932     France
# 103235      103235         US
# 20948        20948         US
# 115046      115046         US
# 118404      118404  Australia
# ...            ...        ...
# 46688        46688         US
# 31165        31165      Italy
# 102856      102856         US
# 16980        16980  Argentina
# 79072        79072         US
#
#                                               description  \
# 58932   With its 50% Sémillon, this ripe wine has the ...
# 103235  Concentrated, bright and focused fruit flavors...
# 20948   This 60% Merlot and 40% Cabernet Sauvignon ble...
# 115046  One of the better Sangioveses out there, altho...
# 118404  This reasonably full-bodied Chardonnay manages...
# ...                                                   ...
# 46688   Made in even smaller amounts than the vintage ...
# 31165   Aromas of toast, scorched earth, black plum, e...
# 102856  Exaggerated, burnt aromas of sun-dried tomato,...
# 16980   Aromas of banana, tropical fruits and spun sug...
# 79072   A brilliant example of how this grape can be d...
#
#                               designation  points  price          province  \
# 58932                     Cuvée des Conti      88   16.0  Southwest France
# 103235                    Perli Vineyards      91   31.0        California
# 20948                  SageCliffe 100 Red      84   22.0        Washington
# 115046                             Estate      87   28.0        California
# 118404                 Tarraford Vineyard      90   42.0          Victoria
# ...                                   ...     ...    ...               ...
# 46688    The Red Hat Old Vine Field Blend      93   37.0        California
# 31165                      Conca Tre Pile      90   35.0          Piedmont
# 102856  Picnic Hill Vineyard Late Harvest      82   14.0        California
# 16980      Phebus Un-Oaked Estate Bottled      84   12.0  Mendoza Province
# 79072                Boekenoogen Vineyard      94   68.0        California
#
#                      region_1          region_2  \
# 58932            Bergerac Sec               NaN
# 103235        Mendocino Ridge               NaN
# 20948    Columbia Valley (WA)   Columbia Valley
# 115046          Amador County  Sierra Foothills
# 118404           Yarra Valley               NaN
# ...                       ...               ...
# 46688             Napa Valley              Napa
# 31165          Barbera d'Alba               NaN
# 102856          Amador County  Sierra Foothills
# 16980                 Mendoza               NaN
# 79072   Santa Lucia Highlands     Central Coast
#
#                                                     title  \
# 58932   Château Tour des Gendres 2014 Cuvée des Conti ...
# 103235  Edmeades 2013 Perli Vineyards Zinfandel (Mendo...
# 20948   Cave B 2005 SageCliffe 100 Red Red (Columbia V...
# 115046  IL Gioiello 2006 Estate Sangiovese (Amador Cou...
# 118404  Giant Steps 2013 Tarraford Vineyard Chardonnay...
# ...                                                   ...
# 46688   Sheldon 2015 The Red Hat Old Vine Field Blend ...
# 31165   Poderi Aldo Conterno 2012 Conca Tre Pile  (Bar...
# 102856  Audubon Cellars 1997 Picnic Hill Vineyard Late...
# 16980   Fabre Montmayou 2013 Phebus Un-Oaked Estate Bo...
# 79072   Mooney Family 2014 Boekenoogen Vineyard Pinot ...
#
#                            variety                    winery
# 58932   Bordeaux-style White Blend  Château Tour des Gendres
# 103235                   Zinfandel                  Edmeades
# 20948                    Red Blend                    Cave B
# 115046                  Sangiovese               IL Gioiello
# 118404                  Chardonnay               Giant Steps
# ...                            ...                       ...
# 46688                    Red Blend                   Sheldon
# 31165                      Barbera      Poderi Aldo Conterno
# 102856                   Zinfandel           Audubon Cellars
# 16980                   Chardonnay           Fabre Montmayou
# 79072                   Pinot Noir             Mooney Family
#
# [1000 rows x 12 columns]

# %%
map_sample_pd.to_csv('../Resources/map_sample1000.csv', encoding='utf-8')
